# %% [markdown]
# <a href="https://colab.research.google.com/github/Letch49/ML_vvsu_2024/blob/master/lab1/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %%
import pandas as pd

# %%
df = pd.read_csv("Global YouTube Statistics.csv", encoding='unicode_escape')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
#Колонки
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#Первые 5 значений
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
#Последние 5 значений
df.tail()
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
#Статистику
df.describe(include='all')
# Out:
#              rank  Youtuber   subscribers   video views       category  \
# count   995.00000       995  9.950000e+02  9.950000e+02            949
# unique        NaN       995           NaN           NaN             18
# top           NaN  T-Series           NaN           NaN  Entertainment
# freq          NaN         1           NaN           NaN            241
# mean    498.00000       NaN  2.298241e+07  1.103954e+10            NaN
# std     287.37606       NaN  1.752611e+07  1.411084e+10            NaN
# min       1.00000       NaN  1.230000e+07  0.000000e+00            NaN
# 25%     249.50000       NaN  1.450000e+07  4.288145e+09            NaN
# 50%     498.00000       NaN  1.770000e+07  7.760820e+09            NaN
# 75%     746.50000       NaN  2.460000e+07  1.355470e+10            NaN
# max     995.00000       NaN  2.450000e+08  2.280000e+11            NaN
#
#           Title        uploads        Country Abbreviation   channel_type  \
# ...

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %%
df.mean(numeric_only=True)
# Out:
# rank                                       4.980000e+02
# subscribers                                2.298241e+07
# video views                                1.103954e+10
# uploads                                    9.187126e+03
# video_views_rank                           5.542489e+05
# country_rank                               3.860535e+02
# channel_type_rank                          7.457193e+02
# video_views_for_the_last_30_days           1.756103e+08
# lowest_monthly_earnings                    3.688615e+04
# highest_monthly_earnings                   5.898078e+05
# lowest_yearly_earnings                     4.422574e+05
# highest_yearly_earnings                    7.081814e+06
# subscribers_for_last_30_days               3.490791e+05
# created_year                               2.012630e+03
# created_date                               1.574646e+01
# Gross tertiary education enrollment (%)    6.362775e+01
# Population                                 4.303873e+08
# ...

# %%
df.min(numeric_only=True)
# Out:
# rank                                       1.000000e+00
# subscribers                                1.230000e+07
# video views                                0.000000e+00
# uploads                                    0.000000e+00
# video_views_rank                           1.000000e+00
# country_rank                               1.000000e+00
# channel_type_rank                          1.000000e+00
# video_views_for_the_last_30_days           1.000000e+00
# lowest_monthly_earnings                    0.000000e+00
# highest_monthly_earnings                   0.000000e+00
# lowest_yearly_earnings                     0.000000e+00
# highest_yearly_earnings                    0.000000e+00
# subscribers_for_last_30_days               1.000000e+00
# created_year                               1.970000e+03
# created_date                               1.000000e+00
# Gross tertiary education enrollment (%)    7.600000e+00
# Population                                 2.025060e+05
# ...

# %%
df.max(numeric_only=True)
# Out:
# rank                                       9.950000e+02
# subscribers                                2.450000e+08
# video views                                2.280000e+11
# uploads                                    3.013080e+05
# video_views_rank                           4.057944e+06
# country_rank                               7.741000e+03
# channel_type_rank                          7.741000e+03
# video_views_for_the_last_30_days           6.589000e+09
# lowest_monthly_earnings                    8.509000e+05
# highest_monthly_earnings                   1.360000e+07
# lowest_yearly_earnings                     1.020000e+07
# highest_yearly_earnings                    1.634000e+08
# subscribers_for_last_30_days               8.000000e+06
# created_year                               2.022000e+03
# created_date                               3.100000e+01
# Gross tertiary education enrollment (%)    1.131000e+02
# Population                                 1.397715e+09
# ...

# %% [markdown]
# 1.   **Ответ 1.**
# 2.   **Ответ 2.**

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# ...

# %%
df.Youtuber = df.Youtuber.astype("category")

df.subscribers = df.subscribers.astype("float")

df.uploads = df.uploads.astype("int")
#Вывести типы колонок тут
df.dtypes
# Out:
# rank                                          int64
# Youtuber                                   category
# subscribers                                 float64
# video views                                 float64
# category                                     object
# Title                                        object
# uploads                                       int32
# Country                                      object
# Abbreviation                                 object
# channel_type                                 object
# video_views_rank                           category
# country_rank                                float64
# channel_type_rank                           float64
# video_views_for_the_last_30_days            float64
# lowest_monthly_earnings                     float64
# highest_monthly_earnings                    float64
# lowest_yearly_earnings                      float64
# highest_yearly_earnings                     float64
# ...

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# #Ответ
# = числовые порядковые(video_views_rank, channel_type_rank), категориальный номинальные(category, Country), числовые количественные(subscribers, video views)

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#Фильтр колонки 1
df[(df['rank'] > 5) & (df['rank'] < 10)]
# Out:
#    rank             Youtuber  subscribers   video views        category  \
# 5     6                Music  119000000.0  0.000000e+00             NaN
# 6     7  ýýý Kids Diana Show  112000000.0  9.324704e+10  People & Blogs
# 7     8            PewDiePie  111000000.0  2.905804e+10          Gaming
# 8     9          Like Nastya  106000000.0  9.047906e+10  People & Blogs
#
#                  Title  uploads        Country Abbreviation   channel_type  \
# 5                Music        0            NaN          NaN          Music
# 6  ýýý Kids Diana Show     1111  United States           US  Entertainment
# 7            PewDiePie     4716          Japan           JP  Entertainment
# 8     Like Nastya Vlog      493         Russia           RU         People
#
#    ... subscribers_for_last_30_days  created_year  created_month  \
# 5  ...                          NaN        2013.0            Sep
# 6  ...                          NaN        2015.0            May
# ...

# %%
#Фильтр колонки 2
df[df['Abbreviation'] == 'US']
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 1       2              YouTube Movies  170000000.0  0.000000e+00
# 2       3                     MrBeast  166000000.0  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 6       7         ýýý Kids Diana Show  112000000.0  9.324704e+10
# 9      10               Vlad and Niki   98900000.0  7.718017e+10
# ..    ...                         ...          ...           ...
# 973   974                        LOUD   12400000.0  2.394143e+09
# 983   984                    MoniLina   12400000.0  1.608681e+10
# 987   988               Avril Lavigne   12400000.0  6.202090e+09
# 988   989                      Caylus   12400000.0  4.779140e+09
# 989   990                   Migos ATL   12400000.0  6.993406e+09
#
#              category                       Title  uploads        Country  \
# 1    Film & Animation               youtubemovies        1  United States
# ...

# %%
#Фильтр колонки 3
df[df['subscribers'] > 80000000]
# Out:
#     rank                    Youtuber  subscribers   video views  \
# 0      1                    T-Series  245000000.0  2.280000e+11
# 1      2              YouTube Movies  170000000.0  0.000000e+00
# 2      3                     MrBeast  166000000.0  2.836884e+10
# 3      4  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 4      5                   SET India  159000000.0  1.480000e+11
# 5      6                       Music  119000000.0  0.000000e+00
# 6      7         ýýý Kids Diana Show  112000000.0  9.324704e+10
# 7      8                   PewDiePie  111000000.0  2.905804e+10
# 8      9                 Like Nastya  106000000.0  9.047906e+10
# 9     10               Vlad and Niki   98900000.0  7.718017e+10
# 10    11           Zee Music Company   96700000.0  5.785629e+10
# 11    12                         WWE   96000000.0  7.742847e+10
# 12    13                      Gaming   93600000.0  0.000000e+00
# 13    14                   BLACKPINK   89800000.0  3.214460e+10
# ...

# %%
df[df['channel_type'] == 'Games']
# Out:
#      rank                                       Youtuber  subscribers  \
# 1       2                                 YouTube Movies  170000000.0
# 12     13                                         Gaming   93600000.0
# 44     45                                    JuegaGerman   48100000.0
# 52     53                                     Fernanfloo   46100000.0
# 77     78                      LUCCAS NETO - LUCCAS TOON   39400000.0
# ..    ...                                            ...          ...
# 979   980  DaniRep | +6 Vï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï   12400000.0
# 988   989                                         Caylus   12400000.0
# 991   992                       Free Fire India Official   12300000.0
# 992   993                                          Panda   12300000.0
# 993   994                                    RobTopGames   12300000.0
#
#       video views          category  \
# 1    0.000000e+00  Film & Animation
# 12   0.000000e+00               NaN
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
#Группировка
df.groupby(['category']).mean(numeric_only=True)
# Out:
#                              rank   subscribers   video views        uploads  \
# category
# Autos & Vehicles       560.500000  1.785000e+07  7.501729e+09    1898.500000
# Comedy                 523.623188  2.012319e+07  7.972649e+09    1119.753623
# Education              477.311111  2.654222e+07  1.548032e+10    3142.866667
# Entertainment          512.551867  2.140332e+07  1.048854e+10   11908.481328
# Film & Animation       361.869565  2.858478e+07  1.183527e+10    2799.652174
# Gaming                 538.191489  2.085213e+07  7.634456e+09    4313.414894
# Howto & Style          594.775000  1.939000e+07  5.045439e+09    1673.350000
# Movies                 241.000000  2.565000e+07  7.691628e+09    3553.000000
# Music                  446.000000  2.571782e+07  1.545286e+10    2335.509901
# News & Politics        506.038462  2.063077e+07  1.039969e+10  112484.384615
# Nonprofits & Activism  314.000000  2.775000e+07  5.431456e+09  102912.000000
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
